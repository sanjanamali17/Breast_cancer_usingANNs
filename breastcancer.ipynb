# %% [markdown]
# # BREAST CANCER PREDICTION USING ANNs ARTIFICIAL NEURAL NETWORKS

# %%
print("hello")
# Out:
# hello

# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r"C:\Users\SANJANA MALI\OneDrive\Attachments\Desktop\Implement ANN\breast-cancer-wisconsin.csv")

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64

# %% [markdown]
# #### DROP UNNECESSARY COLUMNS

# %%
df = df.drop(columns = ['id','Unnamed: 32'])
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
df.shape
# Out:
# (569, 31)

# %%
# change diagnosis column values to 0 and 1
df.loc[df['diagnosis'] == 'M', 'benign_0_mal_1'] = 1
df.loc[df['diagnosis'] == 'B', 'benign_0_mal_1'] = 0
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 0         0.2419  ...          17.33           184.60      2019.0
# 1         0.1812  ...          23.41           158.80      1956.0
# 2         0.2069  ...          25.53           152.50      1709.0
# 3         0.2597  ...          26.50            98.87       567.7
# 4         0.1809  ...          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst  benign_0_mal_1
# 0          0.4601                  0.11890             1.0
# 1          0.2750                  0.08902             1.0
# 2          0.3613                  0.08758             1.0
# 3          0.6638                  0.17300             1.0
# 4          0.2364                  0.07678             1.0
#
# [5 rows x 32 columns]

# %% [markdown]
# #### As i have created a new column called benign_0_mal_1 now i can remove diagnosis.

# %%
df = df.drop(columns = ['diagnosis'])
df.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst  benign_0_mal_1
# 0          0.4601                  0.11890             1.0
# 1          0.2750                  0.08902             1.0
# 2          0.3613                  0.08758             1.0
# 3          0.6638                  0.17300             1.0
# 4          0.2364                  0.07678             1.0
#
# [5 rows x 31 columns]

# %%
X = df.drop(columns=['benign_0_mal_1'])
Y = df['benign_0_mal_1']
X.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((455, 30), (114, 30), (455,), (114,))

# %% [markdown]
# SCALLING

# %%
X.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        symmetry_mean  fractal_dimension_mean  ...  radius_worst  \
# count     569.000000              569.000000  ...    569.000000
# mean        0.181162                0.062798  ...     16.269190
# std         0.027414                0.007060  ...      4.833242
# min         0.106000                0.049960  ...      7.930000
# 25%         0.161900                0.057700  ...     13.010000
# 50%         0.179200                0.061540  ...     14.970000
# 75%         0.195700                0.066120  ...     18.790000
# max         0.304000                0.097440  ...     36.040000
#
#        texture_worst  perimeter_worst   area_worst  smoothness_worst  \
# count     569.000000       569.000000   569.000000        569.000000
# mean       25.677223       107.261213   880.583128          0.132369
# std         6.146258        33.602542   569.356993          0.022832
# min        12.020000        50.410000   185.200000          0.071170
# 25%        21.080000        84.110000   515.300000          0.116600
# 50%        25.410000        97.660000   686.500000          0.131300
# 75%        29.720000       125.400000  1084.000000          0.146000
# max        49.540000       251.200000  4254.000000          0.222600
#
#        compactness_worst  concavity_worst  concave points_worst  \
# count         569.000000       569.000000            569.000000
# mean            0.254265         0.272188              0.114606
# std             0.157336         0.208624              0.065732
# min             0.027290         0.000000              0.000000
# 25%             0.147200         0.114500              0.064930
# 50%             0.211900         0.226700              0.099930
# 75%             0.339100         0.382900              0.161400
# max             1.058000         1.252000              0.291000
#
#        symmetry_worst  fractal_dimension_worst
# count      569.000000               569.000000
# mean         0.290076                 0.083946
# std          0.061867                 0.018061
# min          0.156500                 0.055040
# 25%          0.250400                 0.071460
# 50%          0.282200                 0.080040
# 75%          0.317900                 0.092080
# max          0.663800                 0.207500
#
# [8 rows x 30 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import InputLayer

# %%
model = Sequential()
model.add(InputLayer(input_shape=(30,)))
model.add(Dense(26, activation='relu'))
model.add(Dense(15, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 26)                806
#
#  dense_1 (Dense)             (None, 15)                405
#
#  dense_2 (Dense)             (None, 1)                 16
#
# =================================================================
# Total params: 1227 (4.79 KB)
# Trainable params: 1227 (4.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 15/15 [==============================] - 2s 26ms/step - loss: 0.6920 - accuracy: 0.6330 - val_loss: 0.6772 - val_accuracy: 0.6053
# Epoch 2/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6682 - accuracy: 0.6330 - val_loss: 0.6567 - val_accuracy: 0.6053
# Epoch 3/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6504 - accuracy: 0.6330 - val_loss: 0.6376 - val_accuracy: 0.6053
# Epoch 4/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6309 - accuracy: 0.6330 - val_loss: 0.6158 - val_accuracy: 0.6053
# Epoch 5/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6085 - accuracy: 0.6352 - val_loss: 0.5887 - val_accuracy: 0.6228
# Epoch 6/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5828 - accuracy: 0.6835 - val_loss: 0.5590 - val_accuracy: 0.7105
# Epoch 7/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5567 - accuracy: 0.7648 - val_loss: 0.5289 - val_accuracy: 0.8246
# Epoch 8/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5288 - accuracy: 0.7956 - val_loss: 0.4977 - val_accuracy: 0.8684
# Epoch 9/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5004 - accuracy: 0.8242 - val_loss: 0.4664 - val_accuracy: 0.8772
# Epoch 10/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.4700 - accuracy: 0.8352 - val_loss: 0.4315 - val_accuracy: 0.9123
# Epoch 11/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.4390 - accuracy: 0.8505 - val_loss: 0.4009 - val_accuracy: 0.9298
# Epoch 12/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.4093 - accuracy: 0.8813 - val_loss: 0.3764 - val_accuracy: 0.9298
# Epoch 13/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.3812 - accuracy: 0.8989 - val_loss: 0.3442 - val_accuracy: 0.9298
# Epoch 14/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.3514 - accuracy: 0.9077 - val_loss: 0.3115 - val_accuracy: 0.9298
# Epoch 15/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.3240 - accuracy: 0.9143 - val_loss: 0.2829 - val_accuracy: 0.9298
# Epoch 16/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.2983 - accuracy: 0.9209 - val_loss: 0.2548 - val_accuracy: 0.9386
# Epoch 17/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.2753 - accuracy: 0.9253 - val_loss: 0.2376 - val_accuracy: 0.9298
# Epoch 18/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.2576 - accuracy: 0.9231 - val_loss: 0.2143 - val_accuracy: 0.9298
# Epoch 19/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2403 - accuracy: 0.9275 - val_loss: 0.1991 - val_accuracy: 0.9298
# Epoch 20/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.2254 - accuracy: 0.9319 - val_loss: 0.1913 - val_accuracy: 0.9211
# Epoch 21/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.2115 - accuracy: 0.9341 - val_loss: 0.1762 - val_accuracy: 0.9298
# Epoch 22/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1990 - accuracy: 0.9385 - val_loss: 0.1727 - val_accuracy: 0.9298
# Epoch 23/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1898 - accuracy: 0.9407 - val_loss: 0.1576 - val_accuracy: 0.9298
# Epoch 24/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1786 - accuracy: 0.9473 - val_loss: 0.1478 - val_accuracy: 0.9298
# Epoch 25/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1711 - accuracy: 0.9516 - val_loss: 0.1450 - val_accuracy: 0.9474
# Epoch 26/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1640 - accuracy: 0.9429 - val_loss: 0.1355 - val_accuracy: 0.9474
# Epoch 27/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1562 - accuracy: 0.9538 - val_loss: 0.1315 - val_accuracy: 0.9474
# Epoch 28/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1523 - accuracy: 0.9495 - val_loss: 0.1231 - val_accuracy: 0.9737
# Epoch 29/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1439 - accuracy: 0.9582 - val_loss: 0.1346 - val_accuracy: 0.9298
# Epoch 30/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1399 - accuracy: 0.9604 - val_loss: 0.1142 - val_accuracy: 0.9737
# Epoch 31/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1351 - accuracy: 0.9604 - val_loss: 0.1156 - val_accuracy: 0.9737
# Epoch 32/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1311 - accuracy: 0.9538 - val_loss: 0.1110 - val_accuracy: 0.9737
# Epoch 33/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1257 - accuracy: 0.9604 - val_loss: 0.1032 - val_accuracy: 0.9737
# Epoch 34/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1229 - accuracy: 0.9626 - val_loss: 0.1011 - val_accuracy: 0.9737
# Epoch 35/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1201 - accuracy: 0.9626 - val_loss: 0.0993 - val_accuracy: 0.9825
# Epoch 36/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1147 - accuracy: 0.9670 - val_loss: 0.0975 - val_accuracy: 0.9825
# Epoch 37/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1120 - accuracy: 0.9648 - val_loss: 0.0957 - val_accuracy: 0.9737
# Epoch 38/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1088 - accuracy: 0.9670 - val_loss: 0.0857 - val_accuracy: 0.9825
# Epoch 39/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1067 - accuracy: 0.9670 - val_loss: 0.0833 - val_accuracy: 0.9825
# Epoch 40/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1035 - accuracy: 0.9714 - val_loss: 0.0891 - val_accuracy: 0.9825
# Epoch 41/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1023 - accuracy: 0.9736 - val_loss: 0.0831 - val_accuracy: 0.9825
# Epoch 42/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0990 - accuracy: 0.9692 - val_loss: 0.0798 - val_accuracy: 0.9825
# Epoch 43/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0962 - accuracy: 0.9670 - val_loss: 0.0774 - val_accuracy: 0.9825
# Epoch 44/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0938 - accuracy: 0.9714 - val_loss: 0.0773 - val_accuracy: 0.9912
# Epoch 45/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0995 - accuracy: 0.9736 - val_loss: 0.0742 - val_accuracy: 0.9912
# Epoch 46/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0913 - accuracy: 0.9758 - val_loss: 0.0710 - val_accuracy: 0.9912
# Epoch 47/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0889 - accuracy: 0.9736 - val_loss: 0.0734 - val_accuracy: 0.9825
# Epoch 48/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0873 - accuracy: 0.9780 - val_loss: 0.0717 - val_accuracy: 0.9825
# Epoch 49/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0863 - accuracy: 0.9736 - val_loss: 0.0690 - val_accuracy: 0.9912
# Epoch 50/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0870 - accuracy: 0.9670 - val_loss: 0.0751 - val_accuracy: 0.9825
# Epoch 51/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0855 - accuracy: 0.9780 - val_loss: 0.0678 - val_accuracy: 0.9825
# Epoch 52/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0827 - accuracy: 0.9758 - val_loss: 0.0698 - val_accuracy: 0.9825
# Epoch 53/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0808 - accuracy: 0.9758 - val_loss: 0.0639 - val_accuracy: 0.9912
# Epoch 54/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0799 - accuracy: 0.9780 - val_loss: 0.0677 - val_accuracy: 0.9825
# Epoch 55/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0784 - accuracy: 0.9780 - val_loss: 0.0631 - val_accuracy: 0.9825
# Epoch 56/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0780 - accuracy: 0.9780 - val_loss: 0.0669 - val_accuracy: 0.9825
# Epoch 57/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0777 - accuracy: 0.9736 - val_loss: 0.0606 - val_accuracy: 0.9825
# Epoch 58/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0759 - accuracy: 0.9736 - val_loss: 0.0629 - val_accuracy: 0.9825
# Epoch 59/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0757 - accuracy: 0.9736 - val_loss: 0.0570 - val_accuracy: 0.9912
# Epoch 60/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0758 - accuracy: 0.9758 - val_loss: 0.0582 - val_accuracy: 0.9825
# Epoch 61/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0735 - accuracy: 0.9736 - val_loss: 0.0591 - val_accuracy: 0.9825
# Epoch 62/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0731 - accuracy: 0.9780 - val_loss: 0.0592 - val_accuracy: 0.9825
# Epoch 63/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0726 - accuracy: 0.9758 - val_loss: 0.0594 - val_accuracy: 0.9825
# Epoch 64/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0722 - accuracy: 0.9824 - val_loss: 0.0554 - val_accuracy: 0.9825
# Epoch 65/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0726 - accuracy: 0.9780 - val_loss: 0.0553 - val_accuracy: 0.9825
# Epoch 66/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0736 - accuracy: 0.9802 - val_loss: 0.0521 - val_accuracy: 0.9912
# Epoch 67/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0715 - accuracy: 0.9736 - val_loss: 0.0548 - val_accuracy: 0.9825
# Epoch 68/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0690 - accuracy: 0.9758 - val_loss: 0.0502 - val_accuracy: 0.9912
# Epoch 69/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0693 - accuracy: 0.9780 - val_loss: 0.0610 - val_accuracy: 0.9825
# Epoch 70/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0681 - accuracy: 0.9758 - val_loss: 0.0507 - val_accuracy: 0.9825
# Epoch 71/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0669 - accuracy: 0.9780 - val_loss: 0.0510 - val_accuracy: 0.9825
# Epoch 72/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0664 - accuracy: 0.9736 - val_loss: 0.0560 - val_accuracy: 0.9825
# Epoch 73/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0665 - accuracy: 0.9758 - val_loss: 0.0502 - val_accuracy: 0.9825
# Epoch 74/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0663 - accuracy: 0.9736 - val_loss: 0.0480 - val_accuracy: 0.9912
# Epoch 75/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0655 - accuracy: 0.9824 - val_loss: 0.0501 - val_accuracy: 0.9825
# Epoch 76/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0652 - accuracy: 0.9736 - val_loss: 0.0530 - val_accuracy: 0.9825
# Epoch 77/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0649 - accuracy: 0.9824 - val_loss: 0.0455 - val_accuracy: 1.0000
# Epoch 78/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0634 - accuracy: 0.9802 - val_loss: 0.0593 - val_accuracy: 0.9825
# Epoch 79/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0638 - accuracy: 0.9780 - val_loss: 0.0478 - val_accuracy: 0.9825
# Epoch 80/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0628 - accuracy: 0.9802 - val_loss: 0.0507 - val_accuracy: 0.9825
# Epoch 81/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0634 - accuracy: 0.9802 - val_loss: 0.0501 - val_accuracy: 0.9825
# Epoch 82/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0639 - accuracy: 0.9824 - val_loss: 0.0494 - val_accuracy: 0.9825
# Epoch 83/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0637 - accuracy: 0.9780 - val_loss: 0.0602 - val_accuracy: 0.9825
# Epoch 84/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0632 - accuracy: 0.9802 - val_loss: 0.0483 - val_accuracy: 0.9825
# Epoch 85/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0640 - accuracy: 0.9780 - val_loss: 0.0495 - val_accuracy: 0.9825
# Epoch 86/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0613 - accuracy: 0.9824 - val_loss: 0.0476 - val_accuracy: 0.9825
# Epoch 87/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0612 - accuracy: 0.9780 - val_loss: 0.0518 - val_accuracy: 0.9825
# Epoch 88/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0610 - accuracy: 0.9780 - val_loss: 0.0433 - val_accuracy: 0.9912
# Epoch 89/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0603 - accuracy: 0.9802 - val_loss: 0.0516 - val_accuracy: 0.9825
# Epoch 90/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0587 - accuracy: 0.9780 - val_loss: 0.0415 - val_accuracy: 1.0000
# Epoch 91/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0600 - accuracy: 0.9780 - val_loss: 0.0477 - val_accuracy: 0.9825
# Epoch 92/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0605 - accuracy: 0.9780 - val_loss: 0.0470 - val_accuracy: 0.9825
# Epoch 93/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0606 - accuracy: 0.9802 - val_loss: 0.0451 - val_accuracy: 0.9912
# Epoch 94/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0697 - accuracy: 0.9736 - val_loss: 0.0492 - val_accuracy: 0.9825
# Epoch 95/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0662 - accuracy: 0.9802 - val_loss: 0.0572 - val_accuracy: 0.9737
# Epoch 96/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0575 - accuracy: 0.9868 - val_loss: 0.0405 - val_accuracy: 0.9912
# Epoch 97/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0597 - accuracy: 0.9824 - val_loss: 0.0481 - val_accuracy: 0.9912
# Epoch 98/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0573 - accuracy: 0.9868 - val_loss: 0.0438 - val_accuracy: 0.9912
# Epoch 99/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0582 - accuracy: 0.9802 - val_loss: 0.0448 - val_accuracy: 0.9912
# Epoch 100/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0566 - accuracy: 0.9824 - val_loss: 0.0433 - val_accuracy: 0.9912

# %%
import matplotlib.pyplot as plt
model_loss = pd.DataFrame(model.history.history)
model_loss.plot()
plt.show()

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=20)
model.fit(X_train, y_train, epochs=100, 
            validation_data=(X_test, y_test), 
            callbacks=[early_stop])
# Out:
# Epoch 1/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0585 - accuracy: 0.9824 - val_loss: 0.0489 - val_accuracy: 0.9825
# Epoch 2/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0561 - accuracy: 0.9802 - val_loss: 0.0438 - val_accuracy: 0.9912
# Epoch 3/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0620 - accuracy: 0.9824 - val_loss: 0.0480 - val_accuracy: 0.9912
# Epoch 4/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0586 - accuracy: 0.9824 - val_loss: 0.0466 - val_accuracy: 0.9912
# Epoch 5/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0550 - accuracy: 0.9802 - val_loss: 0.0425 - val_accuracy: 0.9912
# Epoch 6/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0571 - accuracy: 0.9846 - val_loss: 0.0438 - val_accuracy: 0.9912
# Epoch 7/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0549 - accuracy: 0.9824 - val_loss: 0.0421 - val_accuracy: 0.9912
# Epoch 8/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0549 - accuracy: 0.9824 - val_loss: 0.0506 - val_accuracy: 0.9825
# Epoch 9/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0538 - accuracy: 0.9824 - val_loss: 0.0407 - val_accuracy: 0.9912
# Epoch 10/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0553 - accuracy: 0.9846 - val_loss: 0.0495 - val_accuracy: 0.9825
# Epoch 11/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0551 - accuracy: 0.9824 - val_loss: 0.0429 - val_accuracy: 0.9912
# Epoch 12/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0572 - accuracy: 0.9824 - val_loss: 0.0468 - val_accuracy: 0.9825
# Epoch 13/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0535 - accuracy: 0.9802 - val_loss: 0.0420 - val_accuracy: 0.9912
# Epoch 14/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0538 - accuracy: 0.9824 - val_loss: 0.0462 - val_accuracy: 0.9825
# Epoch 15/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0543 - accuracy: 0.9824 - val_loss: 0.0412 - val_accuracy: 0.9912
# Epoch 16/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0549 - accuracy: 0.9824 - val_loss: 0.0475 - val_accuracy: 0.9825
# Epoch 17/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0533 - accuracy: 0.9846 - val_loss: 0.0429 - val_accuracy: 0.9912
# Epoch 18/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0532 - accuracy: 0.9824 - val_loss: 0.0436 - val_accuracy: 0.9825
# Epoch 19/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0525 - accuracy: 0.9824 - val_loss: 0.0418 - val_accuracy: 0.9912
# Epoch 20/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0533 - accuracy: 0.9846 - val_loss: 0.0416 - val_accuracy: 0.9912
# Epoch 21/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0517 - accuracy: 0.9824 - val_loss: 0.0459 - val_accuracy: 0.9912
# Epoch 22/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0517 - accuracy: 0.9802 - val_loss: 0.0429 - val_accuracy: 0.9912
# Epoch 23/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0538 - accuracy: 0.9846 - val_loss: 0.0427 - val_accuracy: 0.9912
# Epoch 24/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0532 - accuracy: 0.9824 - val_loss: 0.0459 - val_accuracy: 0.9912
# Epoch 25/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0522 - accuracy: 0.9868 - val_loss: 0.0413 - val_accuracy: 0.9912
# Epoch 26/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0512 - accuracy: 0.9824 - val_loss: 0.0425 - val_accuracy: 0.9912
# Epoch 27/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0519 - accuracy: 0.9868 - val_loss: 0.0349 - val_accuracy: 0.9912
# Epoch 28/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0521 - accuracy: 0.9846 - val_loss: 0.0512 - val_accuracy: 0.9825
# Epoch 29/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0523 - accuracy: 0.9868 - val_loss: 0.0354 - val_accuracy: 0.9912
# Epoch 30/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0522 - accuracy: 0.9780 - val_loss: 0.0403 - val_accuracy: 0.9912
# Epoch 31/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0513 - accuracy: 0.9802 - val_loss: 0.0436 - val_accuracy: 0.9912
# Epoch 32/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0500 - accuracy: 0.9846 - val_loss: 0.0398 - val_accuracy: 0.9912
# Epoch 33/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0558 - accuracy: 0.9824 - val_loss: 0.0496 - val_accuracy: 0.9912
# Epoch 34/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0578 - accuracy: 0.9802 - val_loss: 0.0393 - val_accuracy: 0.9912
# Epoch 35/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0588 - accuracy: 0.9846 - val_loss: 0.0393 - val_accuracy: 0.9912
# Epoch 36/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0516 - accuracy: 0.9824 - val_loss: 0.0458 - val_accuracy: 0.9912
# Epoch 37/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0498 - accuracy: 0.9802 - val_loss: 0.0363 - val_accuracy: 0.9912
# Epoch 38/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0502 - accuracy: 0.9868 - val_loss: 0.0403 - val_accuracy: 0.9912
# Epoch 39/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0497 - accuracy: 0.9802 - val_loss: 0.0498 - val_accuracy: 0.9825
# Epoch 40/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0494 - accuracy: 0.9824 - val_loss: 0.0416 - val_accuracy: 0.9912
# Epoch 41/100
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0490 - accuracy: 0.9824 - val_loss: 0.0405 - val_accuracy: 0.9912
# Epoch 42/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0520 - accuracy: 0.9824 - val_loss: 0.0379 - val_accuracy: 0.9912
# Epoch 43/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0520 - accuracy: 0.9846 - val_loss: 0.0419 - val_accuracy: 0.9912
# Epoch 44/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0493 - accuracy: 0.9824 - val_loss: 0.0496 - val_accuracy: 0.9825
# Epoch 45/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0509 - accuracy: 0.9824 - val_loss: 0.0380 - val_accuracy: 0.9912
# Epoch 46/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0489 - accuracy: 0.9824 - val_loss: 0.0412 - val_accuracy: 0.9912
# Epoch 47/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0488 - accuracy: 0.9846 - val_loss: 0.0469 - val_accuracy: 0.9825

# %%
import matplotlib.pyplot as plt
model_loss = pd.DataFrame(model.history.history)
model_loss.plot()
plt.show()

# %%
model.save('breastcancer_model.h5')

# %%
import pickle
with open('breast_cancer_scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

# %%
import tensorflow as tf
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import warnings

warnings.filterwarnings("ignore")

# Load the model
model = tf.keras.models.load_model('breastcancer_model.h5')

# load scalar parameters
# Load fitted scaler
with open("breast_cancer_scaler.pkl", "rb") as f:
    scaler = pickle.load(f)


# Example input data (replace with your own data)
# Ensure you include all 30 features expected by the model
input_data = {
    'radius_mean': [14.0],
    'texture_mean': [20.0],
    'perimeter_mean': [90.0],
    'area_mean': [600.0],
    'smoothness_mean': [0.1],
    'compactness_mean': [0.15],
    'concavity_mean': [0.2],
    'concave points_mean': [0.1],   # FIXED
    'symmetry_mean': [0.2],
    'fractal_dimension_mean': [0.06],

    'radius_se': [0.2],
    'texture_se': [1.0],
    'perimeter_se': [1.5],
    'area_se': [20.0],
    'smoothness_se': [0.005],
    'compactness_se': [0.02],
    'concavity_se': [0.03],
    'concave points_se': [0.01],    # FIXED
    'symmetry_se': [0.03],
    'fractal_dimension_se': [0.004],

    'radius_worst': [16.0],
    'texture_worst': [25.0],
    'perimeter_worst': [105.0],
    'area_worst': [800.0],
    'smoothness_worst': [0.12],
    'compactness_worst': [0.2],
    'concavity_worst': [0.3],
    'concave points_worst': [0.15], # FIXED
    'symmetry_worst': [0.25],
    'fractal_dimension_worst': [0.08]
}


# Convert to DataFrame
input_df = pd.DataFrame(input_data)

# Preprocess the input data (normalize, scale, etc.)
input_array = scaler.transform(input_df)  # Directly use the transformed array

# Make predictions
predictions = model.predict(input_array)

# For binary classification, convert probabilities to class labels
predicted_classes = (predictions > 0.5).astype("int32")  # Assuming a threshold of 0.5

# # Example mapping for binary classification
class_mapping = {0: 'Benign', 1: 'Malignant'}

# List comprehension to map predicted class labels to their corresponding names
predicted_class_names = []
for label in predicted_classes:
    predicted_class_names.append(class_mapping[label[0]])


print(predicted_class_names)
# Out:
# 1/1 [==============================] - 0s 152ms/step
# ['Malignant']
